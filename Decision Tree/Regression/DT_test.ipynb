# %%
# -*- coding: utf-8 -*-
import math
import pandas as pd
import sklearn
import numpy as np
from pyearth import Earth
import matplotlib.pyplot as pyplot 
import seaborn as sns
from scipy.stats import skew, skewtest

train = pd.read_csv("/home/saikat/Documents/2020/Project/Dataset_ML_reg.csv")
test = pd.read_csv("/home/saikat/Documents/2020/Project/Dataset_ML_reg_test.csv")

train.describe()
# Out:
#               year        month          day     day_week   close_norm  \
# count  2610.000000  2610.000000  2610.000000  2610.000000  2610.000000
# mean   2013.491571     6.528736    15.736398     3.999234     0.000784
# std       2.876286     3.450040     8.803216     1.413942     0.015480
# min    2008.000000     1.000000     1.000000     2.000000    -0.084211
# 25%    2011.000000     4.000000     8.000000     3.000000    -0.006747
# 50%    2013.000000     7.000000    16.000000     4.000000     0.000073
# 75%    2016.000000    10.000000    23.000000     5.000000     0.008141
# max    2018.000000    12.000000    31.000000     6.000000     0.188146
#
#          open_norm    high_norm     low_norm   range_norm
# count  2610.000000  2610.000000  2610.000000  2610.000000
# mean      0.000779     0.000746     0.000780     0.154307
# std       0.016098     0.014235     0.015184     0.718611
# min      -0.096846    -0.080913    -0.123607    -2.114471
# 25%      -0.007242    -0.005541    -0.006241    -0.303697
# 50%       0.000000     0.000149     0.000000     0.000000
# 75%       0.008686     0.006842     0.007603     0.396617
# max       0.142209     0.192929     0.142209     7.958861

# %%
train.isnull().values.any()
# Out:
# False

# %%
y_train = train['close_norm']
print(y_train)
# Out:
# 0       0.034346
# 1       0.021851
# 2      -0.011981
# 3       0.022993
# 4       0.015352
#           ...
# 2605   -0.005765
# 2606    0.000000
# 2607    0.010184
# 2608   -0.004011
# 2609    0.009178
# Name: close_norm, Length: 2610, dtype: float64

# %%
X_train = train.drop(['close_norm'], axis=1)
print(X_train)
# Out:
#       year  month  day  day_week  open_norm  high_norm  low_norm  range_norm
# 0     2008     12   29         2  -0.038202  -0.014263 -0.017903    0.049852
# 1     2008     12   30         3   0.044757   0.028949  0.052009   -0.351038
# 2     2008     12   31         4   0.021239   0.001252  0.010713   -0.251491
# 3     2009      1    1         5  -0.014752   0.003086  0.007619   -0.160391
# 4     2009      1    2         6   0.026897   0.024050  0.016815    0.337214
# ...    ...    ...  ...       ...        ...        ...       ...         ...
# 2605  2018     12   24         2  -0.014093  -0.015866 -0.005449   -0.527656
# 2606  2018     12   25         3   0.000000   0.000000  0.000000    0.000000
# 2607  2018     12   26         4  -0.009043   0.003501 -0.010076    1.407910
# 2608  2018     12   27         5   0.021275   0.007799  0.016546   -0.364171
# 2609  2018     12   28         6  -0.005597  -0.000973  0.007245   -0.559706
#
# [2610 rows x 8 columns]

# %%
y_test = test['close_norm']
print(y_test)
# Out:
# 0      0.001288
# 1      0.008549
# 2     -0.007947
# 3     -0.007906
# 4      0.008722
#          ...
# 255   -0.001405
# 256   -0.001815
# 257    0.000000
# 258    0.000000
# 259    0.004077
# Name: close_norm, Length: 260, dtype: float64

# %%
X_test = test.drop(['close_norm'], axis=1)
print(X_test)
# Out:
#      year  month  day  day_week  open_norm  high_norm  low_norm  range_norm
# 0    2018     12   31         2   0.008111   0.002684  0.002419    0.044003
# 1    2019      1    1         3  -0.001335   0.005279 -0.003171    1.267218
# 2    2019      1    2         4   0.002409  -0.001203  0.002167   -0.222479
# 3    2019      1    3         5  -0.004228  -0.006984 -0.005682   -0.117206
# 4    2019      1    4         6  -0.006692   0.002510  0.000087    0.233493
# ..    ...    ...  ...       ...        ...        ...       ...         ...
# 255  2019     12   23         2   0.003538   0.001832 -0.000081    0.254408
# 256  2019     12   24         3  -0.001334  -0.003460  0.001528   -0.528354
# 257  2019     12   25         4   0.000000   0.000000  0.000000    0.000000
# 258  2019     12   26         5   0.000000   0.000000  0.000000    0.000000
# 259  2019     12   27         6  -0.006039   0.001683 -0.005886    1.693001
#
# [260 rows x 8 columns]

# %%
ax = sns.distplot(y_train)
pyplot.show()

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
model = DecisionTreeRegressor(random_state = 0)

# %%
model.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#                       max_leaf_nodes=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=0, splitter='best')

# %%
model.score(X_train, y_train)
# Out:
# 0.9999289099688139

# %%
y_pred = model.predict(X_test)
print(model)
#print(model.summary())
print(y_pred)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#                       max_leaf_nodes=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=0, splitter='best')
# [-6.24356200e-03  5.02173200e-03 -2.81762500e-03 -9.85863800e-03
#   2.73469600e-03  4.72349100e-03  1.30160300e-03  7.03843050e-03
#  -2.81762500e-03 -9.81817000e-04 -1.08376200e-03  3.92938000e-04
#   4.44173600e-03 -6.91207600e-03  4.64165000e-04  1.07882400e-03
#  -1.25385830e-02 -1.26311590e-02 -3.28416400e-03  3.13675700e-03
#  -1.75411065e-02 -2.86553100e-03  5.11547925e-03  1.63683200e-02
#   1.44552320e-02  1.16360600e-03  2.08959900e-03  3.07000000e-05
#   1.40278430e-02 -4.45147500e-03 -4.20593800e-03 -5.45322800e-03
#  -4.52503850e-03  3.96752600e-03 -8.10399600e-03 -2.81375000e-04
#   7.83626750e-03 -2.10285950e-03  8.70748850e-03  5.92195000e-05
#   6.69216100e-03 -7.25538900e-03 -1.30718450e-02 -7.34878900e-03
#   4.75360200e-03  2.18043537e-05  1.06835447e-02  2.08959900e-03
#   5.85826600e-03  3.20726800e-03 -3.34832000e-03  2.17586410e-02
#   1.87742025e-02  4.89418200e-03  2.27798900e-02 -5.36417800e-03
#   2.87036800e-03 -5.21525600e-03  2.18043537e-05 -8.97326500e-03
#  -1.92038150e-02  2.59003900e-02  1.24970230e-02  7.80904000e-03
#  -8.91097000e-04  5.85826600e-03 -4.20593800e-03  5.02173200e-03
#  -3.36712500e-03  8.83675400e-03 -6.91207600e-03  6.98786300e-03
#   4.79949500e-03 -2.12367260e-02  1.29561255e-02  2.86529650e-03
#   1.70787490e-02  2.18043537e-05 -1.20833540e-02  2.18043537e-05
#  -1.75411065e-02  9.79175000e-04  1.01120860e-02 -4.95199550e-03
#   4.73590650e-03  2.18043537e-05  2.52916050e-03  2.18043537e-05
#   3.04404970e-02  8.17790600e-03 -4.45796500e-03 -1.00507055e-02
#  -3.41282500e-03 -1.24144000e-04  4.75360200e-03 -8.70457467e-03
#   8.23371700e-03 -6.91207600e-03  2.93317200e-03  2.44932645e-02
#   4.93006300e-03  5.63000000e-04 -6.05787000e-03  3.97924625e-02
#   1.54531560e-02  1.52316960e-02 -3.13828900e-03 -1.36967150e-03
#   1.57932970e-02 -1.95141150e-02 -9.98845000e-04  5.45286133e-03
#   2.18043537e-05 -6.45138800e-03 -4.77983000e-04  4.72349100e-03
#   1.40057600e-03 -6.99021700e-03 -5.71992300e-03  1.96699450e-03
#  -9.41691800e-03  6.98786300e-03 -6.01907500e-04  1.00846765e-02
#   1.24401000e-04  1.41793790e-02  5.02173200e-03  1.14054470e-02
#   9.74051400e-03 -9.64414000e-04  2.57892000e-04 -5.16089100e-03
#   5.53037700e-03  7.07522600e-03 -4.75105650e-03 -6.45138800e-03
#  -4.08121100e-03 -5.89570000e-04  2.52066300e-03 -6.90379800e-03
#  -1.62509790e-02 -1.10169950e-02  1.91208400e-03 -8.10399600e-03
#  -1.95141150e-02 -1.28223680e-02 -3.36049850e-03 -1.19385720e-02
#   4.27618150e-03  1.91208400e-03 -1.59599900e-03  7.61912700e-03
#  -1.00988107e-02 -2.65690935e-02 -1.33148900e-03 -6.45138800e-03
#   3.55190910e-02 -7.51237850e-03  1.26783090e-02  1.16909260e-02
#   2.18043537e-05 -6.45138800e-03 -3.86468000e-04  2.18043537e-05
#   1.15358300e-03  1.39969510e-02 -1.00522980e-02 -7.12338500e-03
#  -1.79603580e-02  2.25923000e-04  1.84618560e-02  9.02669100e-03
#  -1.22195500e-02 -1.76381770e-02  2.21287450e-03  2.18043537e-05
#  -1.77328987e-02  1.70525220e-02 -3.13828900e-03  3.17475600e-03
#   8.99714400e-03  2.18043537e-05  6.43222300e-03  9.03461200e-03
#   9.83883300e-03  6.89781000e-03 -6.45138800e-03  5.48113733e-03
#  -1.75411065e-02  6.70760010e-02  4.93006300e-03 -3.13828900e-03
#  -1.03011840e-02  2.59003900e-02  2.48535650e-02 -1.79603580e-02
#  -6.45138800e-03  2.18043537e-05  3.67971700e-03 -1.95141150e-02
#  -6.49249333e-04  2.18043537e-05  3.23736680e-02 -1.35059230e-02
#   9.83883300e-03 -5.47214000e-04  1.54303800e-02  5.79135700e-03
#   2.19856075e-02  4.51290087e-03  2.18043537e-05  1.51201220e-02
#  -3.09468000e-04 -1.30681520e-02 -4.16400000e-04  2.18043537e-05
#   1.86386936e-02 -2.51994400e-03  1.18702950e-02  4.79949500e-03
#   6.06215900e-03 -5.16089100e-03  1.26783090e-02  7.30546250e-04
#   1.23966430e-02  2.11218400e-03  2.18043537e-05 -3.13828900e-03
#  -8.99228650e-03  1.28508680e-02  6.62446900e-03  4.44173600e-03
#   9.79283900e-03  4.79949500e-03 -1.09979000e-02  1.38355935e-02
#   8.31922500e-03 -5.87106800e-03 -3.34832000e-03  1.96699450e-03
#  -2.47771200e-03  1.64695200e-03  1.07870420e-02 -2.28747200e-03
#  -1.50540770e-02  6.55907500e-04 -3.60508900e-03 -1.11226380e-02
#   3.01854500e-03  3.01854500e-03  5.42236400e-03  1.40057600e-03
#  -1.82726700e-03  8.62310300e-03  4.44173600e-03 -3.69768400e-03
#   1.59531650e-03  2.18043537e-05  2.18043537e-05 -1.33288470e-02]

# %%
from scipy.stats import pearsonr

mse = sklearn.metrics.mean_squared_error(y_test, y_pred)

rmse = math.sqrt(mse)
y_abs = abs(y_test)
rmse_by_mean = rmse/np.mean(y_abs)
print(rmse_by_mean*100)
# calculate Pearson's correlation
corr, _ = pearsonr(y_test, y_pred)
print('Pearsons correlation: %.3f' % corr)
# Out:
# 111.43932631340485
# Pearsons correlation: 0.685

# %%
pyplot.title("Actual Vs Predicted")
pyplot.plot(y_test , label='Actual')
pyplot.plot(y_pred , linestyle='dashed' , label='Predicted')
pyplot.legend()
pyplot.xlabel('Observation')
pyplot.ylabel('Close Prices')
pyplot.show()

# %%
pyplot.scatter(y_test, y_pred)
pyplot.show()

# %%
plot_lm_1 = pyplot.figure()
plot_lm_1.axes[0] = sns.residplot(y_pred, test.columns[-5], data=test,
                          lowess=True,
                          scatter_kws={'alpha': 0.5},
                          line_kws={'color': 'red', 'lw': 1, 'alpha': 0.8})

plot_lm_1.axes[0].set_title('Residuals vs Fitted')
plot_lm_1.axes[0].set_xlabel('Fitted values')
plot_lm_1.axes[0].set_ylabel('Residuals');
